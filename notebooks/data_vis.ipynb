# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r'E:\Btech project\leaf_disease\feature_files\new_glcm(binary).csv')

# %%
df.head()
# Out:
#                                 name   contrast  dissimilarity  homogeneity  \
# 0  DSC_0100_Brown spot_10_binary.npy  64.003665       0.250995     0.999016
# 1  DSC_0100_Brown spot_11_binary.npy  73.536126       0.288377     0.998869
# 2  DSC_0100_Brown spot_12_binary.npy  58.556545       0.229634     0.999099
# 3  DSC_0100_Brown spot_13_binary.npy  59.918325       0.234974     0.999079
# 4  DSC_0100_Brown spot_14_binary.npy  61.280105       0.240314     0.999058
#
#    correlation    energy  label
# 0     0.953311  0.988906      0
# 1     0.951997  0.987579      0
# 2     0.954353  0.989632      0
# 3     0.954955  0.989254      0
# 4     0.956024  0.988751      0

# %%
df.columns
# Out:
# Index(['name', 'contrast', 'dissimilarity', 'homogeneity', 'correlation',
#        'energy', 'label'],
#       dtype='object')

# %%
df.head()
# Out:
#                                 name   contrast  dissimilarity  homogeneity  \
# 0  DSC_0100_Brown spot_10_binary.npy  64.003665       0.250995     0.999016
# 1  DSC_0100_Brown spot_11_binary.npy  73.536126       0.288377     0.998869
# 2  DSC_0100_Brown spot_12_binary.npy  58.556545       0.229634     0.999099
# 3  DSC_0100_Brown spot_13_binary.npy  59.918325       0.234974     0.999079
# 4  DSC_0100_Brown spot_14_binary.npy  61.280105       0.240314     0.999058
#
#    correlation    energy  label
# 0     0.953311  0.988906      0
# 1     0.951997  0.987579      0
# 2     0.954353  0.989632      0
# 3     0.954955  0.989254      0
# 4     0.956024  0.988751      0

# %%
for i in df.columns[:-1]:
    df[i] = df[i]/df[i].mean()

# %%
df.head()
# Out:
#    contrast  dissimilarity  homogeneity       ASM    energy  \
# 0  0.368565       0.443015     1.047733  1.125594  1.073811
# 1  0.024183       0.061806     1.103781  1.298762  1.153458
# 2  0.100827       0.137394     1.089671  1.252063  1.132532
# 3  1.601552       1.532549     0.862337  0.639991  0.809700
# 4  0.421261       0.495080     1.008313  0.973060  0.998406
#
#                    label
# 0  Bacterial leaf blight
# 1  Bacterial leaf blight
# 2  Bacterial leaf blight
# 3  Bacterial leaf blight
# 4  Bacterial leaf blight

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df, hue='label', height=4).map(plt.scatter, 'energy', 'correlation').add_legend()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df, hue='label', height=5).map(plt.scatter, 'energy', 'dissimilarity').add_legend()

# %%
df.corr()
# Out:
#                contrast  dissimilarity  homogeneity  correlation    energy  \
# contrast       1.000000       0.888127    -0.097672    -0.641965 -0.178177
# dissimilarity  0.888127       1.000000    -0.466530    -0.768906 -0.384698
# homogeneity   -0.097672      -0.466530     1.000000     0.217579  0.808413
# correlation   -0.641965      -0.768906     0.217579     1.000000  0.004046
# energy        -0.178177      -0.384698     0.808413     0.004046  1.000000
# label          0.090882       0.196181    -0.218733    -0.211493 -0.089792
#
#                   label
# contrast       0.090882
# dissimilarity  0.196181
# homogeneity   -0.218733
# correlation   -0.211493
# energy        -0.089792
# label          1.000000

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.set_style('whitegrid')
sns.pairplot(df, hue='label', height=4).add_legend()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df, hue='label', height=10).map(sns.distplot, 'contrast').add_legend()

# %%
sns.boxplot(x='label',y='contrast', data=df)

# %%
sns.violinplot(x='label',y='contrast', data=df)

# %%
# !nvidia-smi
# Out:
# Thu Mar 05 15:35:59 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 441.87       Driver Version: 441.87       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1050   WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   43C    P8    N/A /  N/A |     77MiB /  4096MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from itertools import groupby
a = sorted([1, 2, 1, 3, 2, 1, 2, 3, 4, 5])
for key, value in groupby(a):
    print(key, value)
groupby(a)
# Out:
# 1 <itertools._grouper object at 0x00000186439C3550>
# 2 <itertools._grouper object at 0x00000186439C3430>
# 3 <itertools._grouper object at 0x00000186439C3F70>
# 4 <itertools._grouper object at 0x0000018644559F40>
# 5 <itertools._grouper object at 0x0000018644C9FCA0>

# %%
import torch

# %%
x = torch.randn(16, 3, 224, 224)

# %%
assert x.numel() == 16*3*224*224
